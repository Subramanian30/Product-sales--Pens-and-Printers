# %% [markdown]
# # Data Analyst Professional Practical Exam Submission

# %% [markdown]
# ## Data Validation
#
# The Dataset contains a total of **15000 rows and 8 columns** before cleaning and validation. I have validated all columns against the criteria in the dataset table :
#
#  1.week : We have 6 weeks without missing values , same as the description. No cleaning was needed
#
#  2.sales_method : We have 5 sales(em + call should be taken as Email + Call and email taken as Email) method without                   missing values , same as the description.Cleaning was needed, as the em + call was replaced as                       Email + Call
#
#  3.Customer_id : We have 15000 distinct Customer_id values present without any missing values , same as                                description.No cleaning was required.
#
#  4.nb_sold : We have 10 distinct nb_sold values without any missing values , same as description. No                              cleaning was required
#
#  5.revenue : We have 3252 distinct values with 1074 missing values, same as description. We have cleaned                          the dataset and removed those missing rows as revenue is one of our important measures , so                          all related rows have been removed.
#
#  6.years_as_customer : We have 42 distinct values without any missing values,same as description. No                                        cleaning was required
#
#  7.nb_site_visits : we have 27 distinct nb_site_visits values without any missing values , same as                                       description . No cleaning was required
#
#  8.state : we have 50 distinct states without any missing values , same as description . No cleaning was                        required.
#
# After Data cleaning and validation we have total 13926 rows and 9 columns without missing values.

# %% [markdown]
# ## How the sales differ between number of Office Stationery sold each sales method
#
# From the 6 weeks of data provided we can figure out that , through Email sales mathod we have sold a large number of office stationery sold with a mean value of 8413 and the majority of value between 1173 and 16833, followed by Call sales method with a mean of 5678 and the majority of value between 2807 and 8441 while Email + Call seems to be the least efficient sales method
#
# ![Breakdown by category](box1.png)

# %% [markdown]
# ## How much the Sales contact Differ Between Weeks?
#
# Across the 6 weeks , we have contacted different customers. This graph shows the weekly customer contacted data and we have found from this graph , that week 5 have the highest cutomers contacted with 11830 customers followed by week 4 with 9548 customers. The lowest being week 1 with 3497 customers.
#
# ![Breakdown by category](barweek.jpg)

# %% [markdown]
# ## Which States have we contacted more ?
#
# From this map visual we can clearly see that california is the state that we have contacted more (bubble size indicates the count) to sell our products and california hasn't let us down , as the below graph shows california is the state that generated the most revenue , on the other hand north dakota is both the least contacted and least revenue generated state
#
# ![Breakdown by category](map.jpg) ![Breakdown by category](revenue.jpg)

# %% [markdown]
# ## How many customers were there for each approach?
#
# We have had around 15000 distinct customer contacted and it has been noted that Email was the most used approach to contact the customers followed by call and Email + Call with count of 6922 , 4781 , 2223 respectively
#
# ![Breakdown by category](countsalesmethod.jpg)

# %% [markdown]
# ## What does the spread of the revenue look like overall? And for each method?
#
# In total we have genrated a total revenue of 1.31M , when splitting up this revenue for each each sales method we can see Email leading the charts with a revenue of 672K since it was teh sales method with the most customers contacted. Folowing it up are call , Email + call with revenues of 400K and 220K
#
# ![Breakdown by category](revenuemethod.jpg)

# %% [markdown]
# ## Was there any difference in revenue over time for each of the methods?
#
# Yes, We have seen the highest revenue in week 1 and from there , it is a huge decrease in week 2 . Then the revenue has significant rise in week 4 and week 5 , closing week 6 with least revenue generated.
#
# ![Breakdown by category](overtime.jpg)

# %% [markdown]
# ## Business Metrics
#
# Since our goal is to increase the total revenue generated by sell the new products , I would recommend we use the **Email + Call sales method** as our key metric.
#
# Since it is the **sales method with the highest revenue generated per sales contact** producing a revenue of 184 $ per sales contact over the 6 weeks of the sales data
#
# ![Breakdown by category](metric.jpg)

# %% [markdown]
# ## Recommendation
#
# For the following weeks, I would recommend we can focus on the following steps:
#
# 1. Using key metrics to monitor whether there is a strong sign to see the sales will increase.
#
# 2. To implement the campaign as soon as possible, we should smartly promote the office stationery in the market:
#
# -                Target Customers who having buying products for around 1 to 3 years
# -                Focus more On Popular states such as California and Texas
#
# 3. Use the Email + Call sales method to contact customers as it seems like customer prefer to know the information
#    well before and then would like a call to say the needs of the product and how the product works.
#
# 4. Data Collection for in-depth analysis
#
# -                Improve data quality- Find out the missing revenues generated values , as it can change the analysis
# -                New related data - Age of the customer to know their trend and products they wish to buy?
